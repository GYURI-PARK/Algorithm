# %% [markdown]
# <a href="https://colab.research.google.com/github/GYURI-PARK/baekjoon/blob/main/20220916ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1351번 : 무한 수열

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 2002번 : 추월

n = int(input())
in_order = {}
out_order = {}
for i in range(n):
  in_order[input()] = i+1

for i in range(n):
  out_order[input()] = i+1

# in_order 의 첫번째 값보다 앞에있는 차들 뽑기
# out_order에서의 순서값 찾기
firt = 0
cnt = 0
for i,j in in_order.items():
  if j == 1:
    first = out_order[i]
    cnt += first - 1
  # for k in range(first, n):
  #   if j == 2 :
  #     first = out_order[i]



cnt += first - 1
# 일단 first 값 - 1명이 추월 한거임.
# 젤 먼저 나와야 되는 차보다 먼저 나옴

# 그 다음은 무조건 b

print(cnt)
# Out:
# 6
# a
# b
# c
# d
# e
# f
# f
# e
# a
# d
# c
# b
# 3

# %% [markdown]
# d a c b

# %%
in_order
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
first
# Out:
# 3

# %%
out_order
# Out:
# {'f': 1, 'e': 2, 'a': 3, 'd': 4, 'c': 5, 'b': 6}

# %% [markdown]
# C A D B E
#
# C A D E B

# %%
# in_order 의 첫번째 값보다 앞에있는 차들 뽑기
# out_order에서의 순서값 찾기
firt = 0
cnt = 0
for i,j in in_order.items():
  if j == 1:
    first = out_order[i]
  for m,n in out_order.items():
    if n > first and i == m and n < j + first - 1:
      print(m,n)
      cnt += 1


cnt += first - 1
# 일단 first 값 - 1명이 추월 한거임.
# 젤 먼저 나와야 되는 차보다 먼저 나옴
print(cnt)
# Out:
# C 3
# 2

# %%
out_order
# Out:
# {'D': 1, 'A': 2, 'C': 3, 'B': 4}

# %%
# in_order의 첫번 째 값부터만 생각하면 됨
# 원래 value 값보다 크거나 같으면 됨
