# %% [markdown]
# # 10828번 : 스택

# %%
n = int(input())
li = []

for i in range(n):
    order = input().split()
    if 'push' in order :
        li.append(order[1])
    elif order[0] == 'top':
        if len(li) != 0 :
            print(li[len(li)-1])
        else:
            print(-1)
    elif order[0] == 'size':
        print(len(li))
    elif order[0] == 'empty':
        if len(li) == 0:
            print(1)
        else:
            print(0)
    else :
        if len(li) == 0:
            print(-1)
        else:
            print(li.pop())
# Out:
# 3
# push 2
# push 2
# pop
# 2

# %%
li = [1,2,3,4]

# %%
import queue

q = queue.Queue()
q.put('a')

# %%
q.empty()
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
