# %% [markdown]
# <a href="https://colab.research.google.com/github/GYURI-PARK/baekjoon/blob/main/20220911.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 10816번 : 숫자 카드 2

n = int(input())
nli = input().split()

m = int(input())
mli = input().split()

dic = {}
count = 0
for i in mli:
  if i in nli:
    count += 1
    dic[i] = count
  else:
    dic[i] = count

print(dic)
# for i,j in dic.items():
#   if i in nli:
#     dic[i] += 1

#   else :
#     dic[i] = 0
# Out:
# 10
# 6 3 2 10 10 10 -10 -10 7 3
# 8
# 10 9 -5 2 3 4 5 -10
# {'10': 1, '9': 1, '-5': 1, '2': 2, '3': 3, '4': 3, '5': 3, '-10': 4}

# %% [markdown]
# 10
#
# 6 3 2 10 10 10 -10 -10 7 3
#
# 8
#
# 10 9 -5 2 3 4 5 -10

# %%
dic.keys()
# Out:
# dict_keys(['10', '9', '-5', '2', '3', '4', '5', '-10'])
