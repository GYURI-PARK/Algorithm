# %% [markdown]
# <a href="https://colab.research.google.com/github/GYURI-PARK/baekjoon/blob/main/20220821.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 백준 알고리즘 18870번 : 좌표 압축

# %%
import sys
n = int(input())
li = []
li.append(list(sys.stdin.readline().split()))
# li 리스트 안에 list형태로 숫자들을 받아줌

res = list(set(li[0]))
# 중복이 제거된 형태의 list

res.sort(key = lambda x:x)
# 오름차순의 형태로 list를 나열

for i in li[0]:
    for j in range(len(res)):
        if i == res[j]:
            print(j, sep=' ', end=' ')
# li의 값 하나마다 res와 같은 값일 때 res의 인덱스 값을 출력

# %%
import sys
n = int(input())
li_dic = {}
li = []
li.append(list(sys.stdin.readline().split()))
res = list(set(li[0]))
res.sort(key = lambda x:int(x))
# 그냥 x로 해주게 되면 숫자의 첫번째 자리만으로 순서를 정하기 때문에 
# 1000, 999 비교시 1000이 999보다 작은 숫자로 취급되게 된다.

for i in range(len(res)):
    li_dic[res[i]] = i
# li_dic의 key값은 입력된 숫자(중복 포함x)
# value값은 res의 인덱스 값이므로 숫자가 작은 수부터 0,1,2, ... 의 값을 가지게 된다.
  
for i in li[0]:
    print(li_dic[i], sep=' ', end = ' ')
# li의 숫자와 값은 숫자의 value값을 출력
# Out:
# 5

# %%
n = int(input())
li_dic = {}
li = []
li.append(list(input().split()))
res = list(set(li[0]))
res.sort(key = lambda x:int(x))
for i in range(len(res)):
    li_dic[res[i]] = i
for i in li[0]:
    print(li_dic[i], sep=' ', end = ' ')
# Out:
# 5
# 2 4 -10 4 -9
# 2 3 0 3 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 4673번 : 셀프 넘버

natural_num = set(range(1, 10001))
nonself_num = set()
for i in range(1, 10001):
  for j in str(i):
    i += int(j)
  nonself_num.add(i)

self_num = sorted(natural_num - nonself_num)
for i in self_num:
  print(i)
