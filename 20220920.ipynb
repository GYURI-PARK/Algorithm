# %% [markdown]
# <a href="https://colab.research.google.com/github/GYURI-PARK/baekjoon/blob/main/20220920.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2343번 : 기타레슨

# %%
# import sys
# input = sys.stdin.readline

n,m = map(int,input().split())
data = list(map(int,input().split()))


# 순서를 유지해야 하므로 정렬을 사용하면 안된다.
# 이분탐색을 두번 적용 시켜서 
num = sum(data)

start = 0 # num // 3
end = sum(data)
result = num

while start <= end:
    # mid 는 블루레이 크기
    mid = (start + end) // 2 
    if mid < max(data):
        start = mid + 1
        continue
    # cnt 는 블루레이 개수 , tmp 는 블루레이 갱신해주고 있는 블루레이 길이
    cnt,tmp = 1,0
    # 하나씩 더하면서 갱신해준다. 
    for i in range(len(data)):
        # 이전 값이랑 지금 값 더해서 mid 보다 작으면 계속 더해준다
        if tmp + data[i] <= mid:
            tmp += data[i]
        # mid 보다 커지면 현재 data[i]가 tmp 로 들어가고
        # 전에 있던 tmp는 0 초기화 해주고 개수 1개 늘려준다.
        else:
            tmp = data[i]
            cnt += 1
    # 개수가 m-1보다 작거나 같으면 이분탐색으로 영상 길이 인 mid값 갱신 로직 실행ㄴ
    if cnt <= m:
        end = mid - 1
        result = min(result,mid)
    else:
        start = mid + 1
print(result)
# Out:
# [[], [], []]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 11729번 : 하노이 탑 이동 순서

# 원반 n개를 이동하는 문제는 원반 n-1개로 이동하는 문제로 세분화되고, 결국 원반 1개를 이동하는 문제로 세분화 된다

k = int(input())
def hanoi(num, start, end):
  if num == 1:
    print(start, end)
# Out:
# 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 2 -> 3
# 3 -> 5

# %%
# 10994번번 : 별 찍기 - 19
    
n = int(input())
arr = [[' '] * (4*n - 3) for _ in range(4*n - 3)]
# 2차원배열쉽게만드는법 point

def star19(num, idx):
  if num == 1:
    arr[idx][idx] = '*'
    return;

  l = 4 * num - 3
  
  for i in range(idx, idx+l):
    #위ㅇㅏ래
    arr[idx][i] = '*'
    arr[idx+l-1][i] = '*'

     # 양옆
    arr[i][idx] = '*'
    arr[i][idx+l-1] = '*'

  return star19(num-1, idx+2)
# num -1, idx+2를 알아차리는게 중요
# idx+2를 하는 이유는 칸이 위아래로 +2씩 된다음 '*' 입력도ㅓㅣㅁ
star19(n,0)

for i in range(4*n-3):
  for j in range(4*n-3):
    print(arr[i][j], end='')
  print()
# Out:
# 3
# *********
# *       *
# * ***** *
# * *   * *
# * * * * *
# * *   * *
# * ***** *
# *       *
# *********

# %%
# 2차배열 쉽게 구현하는 법

arr2 = [[' '] * (4*num - 3) for _ in range(4*num-3)]
arr2
# Out:
# [[' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ']]

# %%
arr = [['' for _ in range(4*2 - 3)] for _ in range(4*2-3)]

# %% [markdown]
# https://study-all-night.tistory.com/6
#
# 하노이탑 이동 순서

# %%
def hanoi_tower(n, start, end) :
    if n == 1 :
        print(start, end)
        return
       
    hanoi_tower(n-1, start, 6-start-end) # 1단계
    print(start, end) # 2단계
    hanoi_tower(n-1, 6-start-end, end) # 3단계
    
n = int(input())
print(2**n-1)
hanoi_tower(n, 1, 3)
# Out:
# 1
# 1
# (1, 3)

# %%
1
