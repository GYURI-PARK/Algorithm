# %% [markdown]
# <a href="https://colab.research.google.com/github/GYURI-PARK/baekjoon/blob/main/20220905.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 11729번 : 하노이 탑 이동 순서

# 중간에 맨 마지막꺼 빼고 다쌓기
# -> 맨 마지막꺼 3번으로 옮기기
# 홀수일 때, 짝수일 때 나눠서 계산

def hanoi(num):
  cnt = 0
  res = []

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 2798번 : 블랙잭

n, m = map(int, input().split())
res = input().split()

sum = 0
# n이 4이상 일 경우
for i in range(n):
  for j in range(i+1,n-1):
    for k in range(2, n-2):
# Out:
# 4 5
# 5 7 89

# %%
for i in range(2,2):
  print(i)
