# %% [markdown]
# <a href="https://colab.research.google.com/github/GYURI-PARK/baekjoon/blob/main/20220915.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 2910번 : 빈도 정렬
# 자료 구조
# 정렬
# 해시를 사용한 집합과 맵
# 트리를 사용한 집합과 맵


# dictionary 사용
# 문제 n,c가 하는 역할이 없음..


n,c = map(int, input().split())
li = []
li.append(input().split())
li = li[0]
dic = {}
for i in li:
  if i not in dic:
    dic[i] = 1
  else:
    dic[i] += 1
dic = sorted(dic.items(), key=lambda x : -x[1])
for i in range(len(dic)):
  print((dic[i][0]+' ') * dic[i][1], end='')

# 맞았습니다
# n,c 살려서 다시 풀어보기ㅠㅠㅠㅠ
# Out:
# 2 2
# 3 3 2 2
# 3 3 2 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 13414번 : 수강신청
# 구현
# 자료 구조
# 해시를 사용한 집합과 맵
# Out:
# 3 8
# 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-efe9d95ab79d> in <module>
#      10   s = int(input())
#      11   while (True):
# ---> 12     if s not in res:
#      13       res.append(s)
#      14
#
# KeyboardInterrupt:

# %%
s = 1
li = [1,2,3]
if s in li:
  print(s)
# Out:
# 1

# %%
20103324
20133221
20133221
20093778
20140101
01234567
20093778
20103325
# Out:
# {20103324: 1, 20133221: 2, 20093778: 2, 20140101: 1, 1234567: 1, 20103325: 1}

# %%
res
# Out:
# [0, 0, 0]
