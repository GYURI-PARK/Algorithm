# %% [markdown]
# <a href="https://colab.research.google.com/github/GYURI-PARK/baekjoon/blob/main/20220910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def recursion(s, l, r):
    if l >= r: return 1
    elif s[l] != s[r]: return 0
    else: return recursion(s, l+1, r-1)

def isPalindrome(s):
    return recursion(s, 0, len(s)-1)

print('ABBA:', isPalindrome('ABBA'))
print('ABC:', isPalindrome('ABC'))
# Out:
# ABBA: 1
# ABC: 0

# %%
# 25501번 : 재귀의 귀재

n = int(input())

def recursion(s, l, r, cnt):
    if l >= r: 
      cnt += 1
      return [1, cnt]
    elif s[l] != s[r]:
      cnt += 1 
      return [0, cnt]
    else: 
      cnt += 1
      return recursion(s, l+1, r-1, cnt)

def isPalindrome(s, cnt):
    return recursion(s, 0, len(s)-1, cnt)


for i in range(n):
  res = isPalindrome(input(), 0)
  print(res[0], res[1])
# Out:
# 1
# AAA
# 1 2

# %%
Aa
