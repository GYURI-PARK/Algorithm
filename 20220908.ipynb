# %% [markdown]
# <a href="https://colab.research.google.com/github/GYURI-PARK/baekjoon/blob/main/20220908.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1018번 : 체스판 다시 칠하기

n, m = map(int, input().split())
# n : 행, m : 열

arr = [[0 for col in range(m)] for row in range(n)]

for i in range(n):
  arr[i] = input()

line1 = 'WBWBWBWB'
line2 = 'BWBWBWBW'

error = []
cnt = 0

# 행만 이동할 때
# for i in range(n-8+1):
#   for j in range(8):
#     for k in range(8):
#       if  arr[i+j][k] !=

# 행 하나씩 비교해보기

for i in range(n-8+1):
  for j in range(7):
    if arr[0][i+j] == arr[0][i+j+1] :
      cnt += 1

print(cnt)
# Out:
# 1 10
# BBBBBBWWWW
# 0

# %%
arr[0][0] != arr[0][1]
# Out:
# True

# %%
n, m = map(int, input().split())
# n : 행, m : 열

arr = [[0 for col in range(m)] for row in range(n)]

for i in range(n):
  arr[i] = input()
# Out:
# 10 10
# BWBWBWBWBW
# BWBWBWBWBW
# BWBWBWBWBW
# BWBWBWBWBW
# BWBWBWBWBW
# BWBWBWBWBW
# BWBWBWBWBW
# BWBWBWBWBW
# BWBWBWBWBW
# BWBWBWBWBW

# %%
arr[0]
# Out:
# 'BWBWBWBWBW'
